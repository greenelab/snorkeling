# %% [markdown]
# # Using Labels from Different Relation Types to Predict Compound Binds Gene Sentences

# %% [markdown]
# This notebook is designed to predict the compound binds gene (CbG) relation. The first step in this process is to label our train, dev, and test sentences (split = 6,7,8). We will label these sentences using all of our handcrafted label functions. The working hypothesis here is there are shared information between different relations, which in turn should aid in predicting the compound binds gene relation. After the labeling process, the next step is to train a generative model that will estimate the likelihood of the positive class ($\hat{Y}$) given our annotated label matrix. **Note**: This process doesn't involve any sentence context, so the only information used here are categorical output.

# %% [markdown]
# ## Set up the environment

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from collections import defaultdict
import os
import pickle
import sys

sys.path.append(os.path.abspath('../../../modules'))

# Bayesian Optimization
from hyperopt import fmin, hp, tpe, Trials

from itertools import chain
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import sparse
from sklearn.metrics import roc_curve, auc, f1_score, precision_recall_curve, accuracy_score
from tqdm import tqdm_notebook

# %%
#Set up the environment
username = "danich1"
password = "snorkel"
dbname = "pubmeddb"

#Path subject to change for different os
database_str = "postgresql+psycopg2://{}:{}@/{}?host=/var/run/postgresql".format(username, password, dbname)
os.environ['SNORKELDB'] = database_str

from snorkel import SnorkelSession
session = SnorkelSession()

# %%
from snorkel.learning.pytorch.rnn.rnn_base import mark_sentence
from snorkel.learning.pytorch.rnn.utils import candidate_to_tokens
from snorkel.models import Candidate, candidate_subclass

from metal.analysis import lf_summary
from metal.label_model import LabelModel
from metal.utils import plusminus_to_categorical

from gensim.models import FastText
from gensim.models import KeyedVectors

from utils.notebook_utils.label_matrix_helper import label_candidates, get_auc_significant_stats
from utils.notebook_utils.dataframe_helper import load_candidate_dataframes, generate_results_df
from utils.notebook_utils.plot_helper import plot_curve, plot_label_matrix_heatmap
from utils.notebook_utils.train_model_helper import (
    train_baseline_model,
    run_random_additional_lfs
)

sys.path.append(os.path.abspath('../data/label_functions'))
sys.path.append(os.path.abspath('../../../compound_gene/compound_binds_gene/data/label_functions'))
sys.path.append(os.path.abspath('../../../compound_disease/compound_treats_disease/data/label_functions'))
sys.path.append(os.path.abspath('../../../gene_gene/gene_interacts_gene/data/label_functions'))
from compound_gene_lf import CG_LFS
from disease_gene_lfs import DG_LFS
from compound_disease_lf import CD_LFS
from gene_gene_lf import GG_LFS
# Out:
# /home/danich1/anaconda2/envs/snorkeling/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2903: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
DiseaseGene = candidate_subclass('DiseaseGene', ['Disease', 'Gene'])

# %%
quick_load = True

# %% [markdown]
# ## Load the Data and Label the  Sentences

# %% [markdown]
# This block of code is designed to label the sentences using our label functions. All the sentences are located in our postgres database that is store locally on the lab machine. The labeling process is defined as follows: Given a candidate id, we use the sqlalchemy library to extract a candidate object. Using this object and we pass it through a series of label functions that will output a 1 (positive), -1 (negative) or 0 (abstain) depending on the rule set. Lastly we aggregate the output of these functions into a sparse matrix that the generative model will use. Since these steps are pretty linear, we parallelized this process using python's multithreading library. Despite the optimization, this process can still take about 3 hours to label a set of ~300000 sentences.

# %%
total_candidates_df = pd.read_table("../dataset_statistics/results/all_dag_map.tsv.xz")
total_candidates_df.head(2)
# Out:
#    entrez_gene_id gene_symbol    doid_id           doid_name sources  \
# 0               1        A1BG  DOID:2531  hematologic cancer     NaN
# 1               1        A1BG  DOID:2531  hematologic cancer     NaN
#
#    hetionet  n_sentences  has_sentence  partition_rank  split  \
# 0         0            8             1          0.8586      1
# 1         0            8             1          0.8586      1
#
#    compound_mention_count  disease_mention_count  gene_mention_count  \
# 0                     0.0                    1.0                 3.0
# 1                     0.0                    1.0                 3.0
#
#    sentence_id                                               text  sen_length  \
# 0      2129459  The number of H antigen sites per single red c...         172
# 1      2129459  The number of H antigen sites per single red c...         172
#
#    candidate_id
# 0        176680
# 1        176675

# %%
spreadsheet_names = {
    #'train': 'data/sentences/sentence_labels_train.xlsx',
    'dev': '../data/sentences/sentence_labels_dev.xlsx',
    'test': '../data/sentences/sentence_labels_test.xlsx'
}

# %%
candidate_dfs = {
    key:load_candidate_dataframes(spreadsheet_names[key], "curated_dsh")
    for key in spreadsheet_names
}

for key in candidate_dfs:
    print("Size of {} set: {}".format(key, candidate_dfs[key].shape[0]))
# Out:
# Size of dev set: 1000
# Size of test set: 1000

# %%
lfs = (
    list(DG_LFS["DaG"].values()) + 
    list(CD_LFS["CtD"].values())[3:25] + 
    list(CG_LFS["CbG"].values())[9:29] + 
    list(GG_LFS["GiG"].values())[9:37]
)
lf_names = (
    list(DG_LFS["DaG"].keys()) + 
    list(CD_LFS["CtD"].keys())[3:25] + 
    list(CG_LFS["CbG"].keys())[9:29] + 
    list(GG_LFS["GiG"].keys())[9:37]
)

# %%
if not quick_load:
    label_matricies = {
        'train':label_candidates(
            session, 
            (
                total_candidates_df
                .query("split==0&gene_mention_count==1&disease_mention_count==1")
                .candidate_id
                .values
                .tolist()
            ),
            lfs, 
            lf_names,
            num_threads=10,
            batch_size=50000,
            multitask=False
        )
    }

# %%
if not quick_load:
    label_matricies.update({
        key:label_candidates(
            session, 
            candidate_dfs[key]['candidate_id'].values.tolist(),
            lfs, 
            lf_names,
            num_threads=10,
            batch_size=50000,
            multitask=False
        )
        for key in candidate_dfs
    })

# %%
# Save the label matricies to a file for future loading/error analysis
if not quick_load:
    (
        label_matricies['train']
        .sort_values("candidate_id")
        .to_csv("../data/label_matricies/train_sparse_matrix.tsv.xz", sep="\t", index=False)
    )
    (
        label_matricies['dev']
        .sort_values("candidate_id")
        .to_csv("../data/label_matricies/dev_sparse_matrix.tsv.xz", sep="\t", index=False)
    )
    (
        label_matricies['test']
        .sort_values("candidate_id")
        .to_csv("../data/label_matricies/test_sparse_matrix.tsv.xz", sep="\t", index=False)
    )
# Quick load the label matricies
else:
    label_destinations = {
        'train':"../data/label_matricies/train_sparse_matrix.tsv.xz",
        'dev':"../data/label_matricies/dev_sparse_matrix.tsv.xz",
        'test':"../data/label_matricies/test_sparse_matrix.tsv.xz"
    }
    label_matricies = {
        key:pd.read_table(label_destinations[key]).to_sparse()
        for key in label_destinations
    }

# %%
# Important Note Snorkel Metal uses a different coding scheme
# than the label functions output. (2 for negative instead of -1).
# This step corrects this problem by converting -1s to 2

correct_L = plusminus_to_categorical(
    label_matricies['train']
    .sort_values("candidate_id")
    .drop("candidate_id", axis=1)
    .to_coo()
    .toarray()
    .astype(int)
)

correct_L_dev = plusminus_to_categorical(
    label_matricies['dev']
    .sort_values("candidate_id")
    .drop("candidate_id", axis=1)
    .to_coo()
    .toarray()
    .astype(int)
)

correct_L_test = plusminus_to_categorical(
    label_matricies['test']
    .sort_values("candidate_id")
    .drop("candidate_id", axis=1)
    .to_coo()
    .toarray()
    .astype(int)
)

# %%
lf_summary(
    sparse.coo_matrix(
        correct_L
    )
    .tocsr(), 
    lf_names=lf_names
)
# Out:
#                                         j Polarity  Coverage  Overlaps  \
# LF_HETNET_DISEASES                      0        1  0.377833  0.377833
# LF_HETNET_DOAF                          1        1  0.172154  0.172154
# LF_HETNET_DisGeNET                      2        1  0.341907  0.341907
# LF_HETNET_GWAS                          3        1  0.043166  0.043166
# LF_HETNET_DaG_ABSENT                    4        2  0.510921  0.510921
# LF_DG_CHECK_GENE_TAG                    5        2  0.239513  0.239513
# LF_DG_CHECK_DISEASE_TAG                 6        2  0.375861  0.375861
# LF_DG_IS_BIOMARKER                      7        1  0.165462  0.165462
# LF_DaG_ASSOCIATION                      8        1  0.234982  0.234982
# LF_DaG_WEAK_ASSOCIATION                 9        1  0.008548  0.008548
# LF_DaG_NO_ASSOCIATION                  10        2  0.017120  0.017120
# LF_DaG_CELLULAR_ACTIVITY               11        1  0.019648  0.019648
# LF_DaG_DISEASE_SAMPLE                  12        1  0.611488  0.611488
# LF_DG_METHOD_DESC                      13        2  0.136445  0.136445
# LF_DG_TITLE                            14        2  0.041473  0.041473
# LF_DG_GENETIC_ABNORMALITIES            15        1  0.068943  0.068943
# LF_DG_DIAGNOSIS                        16        1  0.019244  0.019244
# LF_DG_PATIENT_WITH                     17        1  0.100350  0.100350
# LF_DG_CONCLUSION_TITLE                 18        1  0.024796  0.024796
# LF_DaG_NO_CONCLUSION                   19        2  0.691845  0.691845
# LF_DaG_CONCLUSION                      20   [1, 2]  0.309848  0.309848
# LF_DG_DISTANCE_SHORT                   21        2  0.149788  0.149788
# LF_DG_DISTANCE_LONG                    22        2  0.000984  0.000984
# LF_DG_ALLOWED_DISTANCE                 23        1  0.849228  0.849228
# LF_DG_NO_VERB                          24        2  0.144035  0.144035
# LF_DG_MULTIPLE_ENTITIES                25        2  0.084890  0.084890
# LF_DG_CONTEXT_SWITCH                   26        2  0.009185  0.009185
# LF_DG_BICLUSTER_CASUAL_MUTATIONS       27        1  0.223386  0.223386
# LF_DG_BICLUSTER_MUTATIONS              28        1  0.207020  0.207020
# LF_DG_BICLUSTER_DRUG_TARGETS           29        1  0.231129  0.231129
# ...                                   ...      ...       ...       ...
# LF_CG_BICLUSTER_AFF_EXPRESSION         77        1  0.028052  0.028052
# LF_CG_BICLUSTER_INHIBITS               78        1  0.015823  0.015823
# LF_GiG_BINDING_IDENTIFICATIONS         79        1  0.010692  0.010692
# LF_GiG_CELL_IDENTIFICATIONS            80        2  0.332226  0.332226
# LF_GiG_COMPOUND_IDENTIFICATIONS        81        2  0.033910  0.033910
# LF_GiG_UPREGULATES                     82        2  0.013726  0.013726
# LF_GiG_DOWNREGULATES                   83        2  0.007671  0.007671
# LF_GiG_REGULATION                      84        2  0.022968  0.022968
# LF_GiG_ASSOCIATION                     85        2  0.053926  0.053926
# LF_GiG_BOUND_IDENTIFIERS               86        1  0.030443  0.030443
# LF_GiG_GENE_IDENTIFIERS                87        1  0.156847  0.156847
# LF_GiG_GENE_ADJECTIVE                  88        2  0.003374  0.003374
# LF_GiG_DIAGNOSIS_IDENTIFIERS           89        2  0.004909  0.004909
# LF_GiG_METHOD_DESC                     90        2  0.016694  0.016694
# LF_GiG_PARENTHESIS                     91        2  0.003515  0.003515
# LF_GG_IN_SERIES                        92        2  0.074749  0.074749
# LF_GiG_NO_CONCLUSION                   93        2  0.877744  0.877744
# LF_GiG_CONCLUSION                      94   [1, 2]  0.122256  0.122256
# LF_GG_DISTANCE_SHORT                   95        2  0.063791  0.063791
# LF_GG_DISTANCE_LONG                    96        2  0.030903  0.030903
# LF_GG_ALLOWED_DISTANCE                 97        1  0.905306  0.905306
# LF_GG_NO_VERB                          98        2  0.144035  0.144035
# LF_GG_BICLUSTER_BINDING                99        1  0.007205  0.007205
# LF_GG_BICLUSTER_ENHANCES              100        1  0.004289  0.004289
# LF_GG_BICLUSTER_ACTIVATES             101        1  0.006632  0.006632
# LF_GG_BICLUSTER_AFFECTS_EXPRESSION    102        1  0.005118  0.005118
# LF_GG_BICLUSTER_INCREASES_EXPRESSION  103        2  0.006717  0.006717
# LF_GG_BICLUSTER_SIGNALING             104        1  0.006412  0.006412
# LF_GG_BICLUSTER_IDENTICAL_PROTEIN     105        2  0.005660  0.005660
# LF_GG_BICLUSTER_CELL_PRODUCTION       106        2  0.006590  0.006590
#
#                                       Conflicts
# LF_HETNET_DISEASES                     0.377810
# LF_HETNET_DOAF                         0.172137
# LF_HETNET_DisGeNET                     0.341890
# LF_HETNET_GWAS                         0.043163
# LF_HETNET_DaG_ABSENT                   0.504998
# LF_DG_CHECK_GENE_TAG                   0.238014
# LF_DG_CHECK_DISEASE_TAG                0.373421
# LF_DG_IS_BIOMARKER                     0.165452
# LF_DaG_ASSOCIATION                     0.234964
# LF_DaG_WEAK_ASSOCIATION                0.008548
# LF_DaG_NO_ASSOCIATION                  0.017022
# LF_DaG_CELLULAR_ACTIVITY               0.019640
# LF_DaG_DISEASE_SAMPLE                  0.611475
# LF_DG_METHOD_DESC                      0.135540
# LF_DG_TITLE                            0.041225
# LF_DG_GENETIC_ABNORMALITIES            0.068941
# LF_DG_DIAGNOSIS                        0.019244
# LF_DG_PATIENT_WITH                     0.100346
# LF_DG_CONCLUSION_TITLE                 0.024796
# LF_DaG_NO_CONCLUSION                   0.686016
# LF_DaG_CONCLUSION                      0.309722
# LF_DG_DISTANCE_SHORT                   0.143940
# LF_DG_DISTANCE_LONG                    0.000910
# LF_DG_ALLOWED_DISTANCE                 0.849199
# LF_DG_NO_VERB                          0.142597
# LF_DG_MULTIPLE_ENTITIES                0.084670
# LF_DG_CONTEXT_SWITCH                   0.009182
# LF_DG_BICLUSTER_CASUAL_MUTATIONS       0.223380
# LF_DG_BICLUSTER_MUTATIONS              0.207020
# LF_DG_BICLUSTER_DRUG_TARGETS           0.231124
# ...                                         ...
# LF_CG_BICLUSTER_AFF_EXPRESSION         0.028052
# LF_CG_BICLUSTER_INHIBITS               0.015823
# LF_GiG_BINDING_IDENTIFICATIONS         0.010691
# LF_GiG_CELL_IDENTIFICATIONS            0.330255
# LF_GiG_COMPOUND_IDENTIFICATIONS        0.033904
# LF_GiG_UPREGULATES                     0.013723
# LF_GiG_DOWNREGULATES                   0.007657
# LF_GiG_REGULATION                      0.022949
# LF_GiG_ASSOCIATION                     0.053893
# LF_GiG_BOUND_IDENTIFIERS               0.030430
# LF_GiG_GENE_IDENTIFIERS                0.156833
# LF_GiG_GENE_ADJECTIVE                  0.003362
# LF_GiG_DIAGNOSIS_IDENTIFIERS           0.004909
# LF_GiG_METHOD_DESC                     0.016603
# LF_GiG_PARENTHESIS                     0.003003
# LF_GG_IN_SERIES                        0.074335
# LF_GiG_NO_CONCLUSION                   0.871830
# LF_GiG_CONCLUSION                      0.122218
# LF_GG_DISTANCE_SHORT                   0.057942
# LF_GG_DISTANCE_LONG                    0.030829
# LF_GG_ALLOWED_DISTANCE                 0.905277
# LF_GG_NO_VERB                          0.142597
# LF_GG_BICLUSTER_BINDING                0.007205
# LF_GG_BICLUSTER_ENHANCES               0.004289
# LF_GG_BICLUSTER_ACTIVATES              0.006632
# LF_GG_BICLUSTER_AFFECTS_EXPRESSION     0.005118
# LF_GG_BICLUSTER_INCREASES_EXPRESSION   0.006714
# LF_GG_BICLUSTER_SIGNALING              0.006412
# LF_GG_BICLUSTER_IDENTICAL_PROTEIN      0.005660
# LF_GG_BICLUSTER_CELL_PRODUCTION        0.006585
#
# [107 rows x 5 columns]

# %%
lf_summary(
    sparse.coo_matrix(
        correct_L_dev
    )
    .tocsr(), 
    lf_names=lf_names, 
    Y=candidate_dfs['dev'].curated_dsh.apply(lambda x: 1 if x> 0 else 2)
)
# Out:
# /home/danich1/Documents/metal/metal/analysis.py:131: RuntimeWarning: invalid value encountered in true_divide
#   return 0.5 * (X.sum(axis=0) / (L != 0).sum(axis=0) + 1)
#                                         j Polarity  Coverage  Overlaps  \
# LF_HETNET_DISEASES                      0        1     0.432     0.432
# LF_HETNET_DOAF                          1        1     0.206     0.206
# LF_HETNET_DisGeNET                      2        1     0.388     0.388
# LF_HETNET_GWAS                          3        1     0.050     0.050
# LF_HETNET_DaG_ABSENT                    4        2     0.459     0.459
# LF_DG_CHECK_GENE_TAG                    5        2     0.265     0.265
# LF_DG_CHECK_DISEASE_TAG                 6        2     0.344     0.344
# LF_DG_IS_BIOMARKER                      7        1     0.167     0.167
# LF_DaG_ASSOCIATION                      8        1     0.258     0.258
# LF_DaG_WEAK_ASSOCIATION                 9        1     0.022     0.022
# LF_DaG_NO_ASSOCIATION                  10        2     0.028     0.028
# LF_DaG_CELLULAR_ACTIVITY               11        1     0.050     0.050
# LF_DaG_DISEASE_SAMPLE                  12        1     0.643     0.643
# LF_DG_METHOD_DESC                      13        2     0.214     0.214
# LF_DG_TITLE                            14        2     0.044     0.044
# LF_DG_GENETIC_ABNORMALITIES            15        1     0.052     0.052
# LF_DG_DIAGNOSIS                        16        1     0.025     0.025
# LF_DG_PATIENT_WITH                     17        1     0.091     0.091
# LF_DG_CONCLUSION_TITLE                 18        1     0.017     0.017
# LF_DaG_NO_CONCLUSION                   19        2     0.789     0.789
# LF_DaG_CONCLUSION                      20   [1, 2]     0.224     0.224
# LF_DG_DISTANCE_SHORT                   21        2     0.120     0.120
# LF_DG_DISTANCE_LONG                    22        2     0.013     0.013
# LF_DG_ALLOWED_DISTANCE                 23        1     0.867     0.867
# LF_DG_NO_VERB                          24        2     0.072     0.072
# LF_DG_MULTIPLE_ENTITIES                25        2     0.729     0.729
# LF_DG_CONTEXT_SWITCH                   26        2     0.016     0.016
# LF_DG_BICLUSTER_CASUAL_MUTATIONS       27        1     0.275     0.275
# LF_DG_BICLUSTER_MUTATIONS              28        1     0.250     0.250
# LF_DG_BICLUSTER_DRUG_TARGETS           29        1     0.298     0.298
# ...                                   ...      ...       ...       ...
# LF_CG_BICLUSTER_AFF_EXPRESSION         77        1     0.032     0.032
# LF_CG_BICLUSTER_INHIBITS               78        1     0.015     0.015
# LF_GiG_BINDING_IDENTIFICATIONS         79        1     0.020     0.020
# LF_GiG_CELL_IDENTIFICATIONS            80        2     0.405     0.405
# LF_GiG_COMPOUND_IDENTIFICATIONS        81        2     0.016     0.016
# LF_GiG_UPREGULATES                     82        2     0.017     0.017
# LF_GiG_DOWNREGULATES                   83        2     0.006     0.006
# LF_GiG_REGULATION                      84        2     0.024     0.024
# LF_GiG_ASSOCIATION                     85        2     0.045     0.045
# LF_GiG_BOUND_IDENTIFIERS               86        1     0.045     0.045
# LF_GiG_GENE_IDENTIFIERS                87        1     0.165     0.165
# LF_GiG_GENE_ADJECTIVE                  88        2     0.003     0.003
# LF_GiG_DIAGNOSIS_IDENTIFIERS           89        2     0.005     0.005
# LF_GiG_METHOD_DESC                     90        2     0.019     0.019
# LF_GiG_PARENTHESIS                     91        2     0.007     0.007
# LF_GG_IN_SERIES                        92        2     0.164     0.164
# LF_GiG_NO_CONCLUSION                   93        2     0.865     0.865
# LF_GiG_CONCLUSION                      94   [1, 2]     0.135     0.135
# LF_GG_DISTANCE_SHORT                   95        2     0.054     0.054
# LF_GG_DISTANCE_LONG                    96        2     0.103     0.103
# LF_GG_ALLOWED_DISTANCE                 97        1     0.843     0.843
# LF_GG_NO_VERB                          98        2     0.072     0.072
# LF_GG_BICLUSTER_BINDING                99        1     0.104     0.104
# LF_GG_BICLUSTER_ENHANCES              100        1     0.071     0.071
# LF_GG_BICLUSTER_ACTIVATES             101        1     0.107     0.107
# LF_GG_BICLUSTER_AFFECTS_EXPRESSION    102        1     0.088     0.088
# LF_GG_BICLUSTER_INCREASES_EXPRESSION  103        2     0.099     0.099
# LF_GG_BICLUSTER_SIGNALING             104        1     0.097     0.097
# LF_GG_BICLUSTER_IDENTICAL_PROTEIN     105        2     0.091     0.091
# LF_GG_BICLUSTER_CELL_PRODUCTION       106        2     0.110     0.110
#
#                                       Conflicts  Correct  Incorrect  Emp. Acc.
# LF_HETNET_DISEASES                        0.432      164        268   0.379630
# LF_HETNET_DOAF                            0.206       80        126   0.388350
# LF_HETNET_DisGeNET                        0.388      144        244   0.371134
# LF_HETNET_GWAS                            0.050       24         26   0.480000
# LF_HETNET_DaG_ABSENT                      0.454      270        189   0.588235
# LF_DG_CHECK_GENE_TAG                      0.264      174         91   0.656604
# LF_DG_CHECK_DISEASE_TAG                   0.343      218        126   0.633721
# LF_DG_IS_BIOMARKER                        0.167      119         48   0.712575
# LF_DaG_ASSOCIATION                        0.258      178         80   0.689922
# LF_DaG_WEAK_ASSOCIATION                   0.022       13          9   0.590909
# LF_DaG_NO_ASSOCIATION                     0.028       23          5   0.821429
# LF_DaG_CELLULAR_ACTIVITY                  0.050       35         15   0.700000
# LF_DaG_DISEASE_SAMPLE                     0.643      242        401   0.376361
# LF_DG_METHOD_DESC                         0.211      206          8   0.962617
# LF_DG_TITLE                               0.044       34         10   0.772727
# LF_DG_GENETIC_ABNORMALITIES               0.052       20         32   0.384615
# LF_DG_DIAGNOSIS                           0.025       12         13   0.480000
# LF_DG_PATIENT_WITH                        0.091       24         67   0.263736
# LF_DG_CONCLUSION_TITLE                    0.017       12          5   0.705882
# LF_DaG_NO_CONCLUSION                      0.784      539        250   0.683143
# LF_DaG_CONCLUSION                         0.224      166         58   0.741071
# LF_DG_DISTANCE_SHORT                      0.118       89         31   0.741667
# LF_DG_DISTANCE_LONG                       0.010       10          3   0.769231
# LF_DG_ALLOWED_DISTANCE                    0.867      363        504   0.418685
# LF_DG_NO_VERB                             0.072       62         10   0.861111
# LF_DG_MULTIPLE_ENTITIES                   0.726      455        274   0.624143
# LF_DG_CONTEXT_SWITCH                      0.016        8          8   0.500000
# LF_DG_BICLUSTER_CASUAL_MUTATIONS          0.275      130        145   0.472727
# LF_DG_BICLUSTER_MUTATIONS                 0.250      111        139   0.444000
# LF_DG_BICLUSTER_DRUG_TARGETS              0.298      141        157   0.473154
# ...                                         ...      ...        ...        ...
# LF_CG_BICLUSTER_AFF_EXPRESSION            0.032       10         22   0.312500
# LF_CG_BICLUSTER_INHIBITS                  0.015        4         11   0.266667
# LF_GiG_BINDING_IDENTIFICATIONS            0.020        8         12   0.400000
# LF_GiG_CELL_IDENTIFICATIONS               0.403      267        138   0.659259
# LF_GiG_COMPOUND_IDENTIFICATIONS           0.016       11          5   0.687500
# LF_GiG_UPREGULATES                        0.017        7         10   0.411765
# LF_GiG_DOWNREGULATES                      0.006        3          3   0.500000
# LF_GiG_REGULATION                         0.024       11         13   0.458333
# LF_GiG_ASSOCIATION                        0.045       10         35   0.222222
# LF_GiG_BOUND_IDENTIFIERS                  0.045       16         29   0.355556
# LF_GiG_GENE_IDENTIFIERS                   0.165       66         99   0.400000
# LF_GiG_GENE_ADJECTIVE                     0.003        2          1   0.666667
# LF_GiG_DIAGNOSIS_IDENTIFIERS              0.005        4          1   0.800000
# LF_GiG_METHOD_DESC                        0.019       18          1   0.947368
# LF_GiG_PARENTHESIS                        0.007        7          0   1.000000
# LF_GG_IN_SERIES                           0.163      120         44   0.731707
# LF_GiG_NO_CONCLUSION                      0.860      531        334   0.613873
# LF_GiG_CONCLUSION                         0.135       60         75   0.444444
# LF_GG_DISTANCE_SHORT                      0.052       41         13   0.759259
# LF_GG_DISTANCE_LONG                       0.100       72         31   0.699029
# LF_GG_ALLOWED_DISTANCE                    0.843      353        490   0.418743
# LF_GG_NO_VERB                             0.072       62         10   0.861111
# LF_GG_BICLUSTER_BINDING                   0.104       39         65   0.375000
# LF_GG_BICLUSTER_ENHANCES                  0.071       27         44   0.380282
# LF_GG_BICLUSTER_ACTIVATES                 0.107       46         61   0.429907
# LF_GG_BICLUSTER_AFFECTS_EXPRESSION        0.088       32         56   0.363636
# LF_GG_BICLUSTER_INCREASES_EXPRESSION      0.099       60         39   0.606061
# LF_GG_BICLUSTER_SIGNALING                 0.097       38         59   0.391753
# LF_GG_BICLUSTER_IDENTICAL_PROTEIN         0.091       53         38   0.582418
# LF_GG_BICLUSTER_CELL_PRODUCTION           0.110       70         40   0.636364
#
# [107 rows x 8 columns]

# %% [markdown]
# # Train Baseline Model

# %% [markdown]
# This block trains the baseline model (Distant Supervision of CbG Databases) that will be used as a reference to compare against.

# %%
ds_start = 0
ds_end = 7
regularization_grid = pd.np.round(pd.np.linspace(0.01, 5, num=5), 2)

# %%
dev_ds_grid, test_ds_grid = train_baseline_model(
    correct_L, correct_L_dev, candidate_dfs['dev'].curated_dsh.values, 
    correct_L_test, list(range(ds_start, ds_end)), regularization_grid,
    train_marginal_dir="results/DaG/marginals/"
)

dev_baseline_marginals = list(dev_ds_grid.values())[0][:,0]
test_baseline_marginals = list(test_ds_grid.values())[0][:,0]

dev_ds_grid = (
    generate_results_df(
        dev_ds_grid, 
        candidate_dfs['dev'].curated_dsh.values
    )
    .reset_index()
    .rename(index=str, columns={0:"AUPRC", 1:"AUROC", "index":"l2_param"})
)

test_ds_grid = (
    generate_results_df(
        test_ds_grid, 
        candidate_dfs['test'].curated_dsh.values
    )
    .reset_index()
    .rename(index=str, columns={0:"AUPRC", 1:"AUROC", "index":"l2_param"})
)

# %%
best_param = dev_ds_grid.query("AUROC==AUROC.max()").l2_param.values[0]
dev_baseline=dev_ds_grid.query("l2_param==@best_param").to_dict('records')
dev_baseline[0].update({"num_lfs": 0})

# %%
test_baseline=test_ds_grid.query("l2_param==@best_param").to_dict('records')
test_baseline[0].update({"num_lfs": 0})

# %%
dev_baseline_marginals = list(zip(dev_baseline_marginals, candidate_dfs['dev'].curated_dsh.values))
test_baseline_marginals = list(zip(test_baseline_marginals, candidate_dfs['test'].curated_dsh.values))

# %%
count_fraction_correct = lambda x: 1 if (x.marginals > 0.5 and x.label==1) or (x.marginals < 0.5 and x.label==0) else 0

# %% [markdown]
# # Random Label Function Positive Direction

# %% [markdown]
# This block is designed to determine how many label functions are needed to achieve decent results.

# %%
num_of_samples = 50
regularization_grid = pd.np.round(pd.np.linspace(0.01, 5, num=5), 2)

# %%
dev_dag_pos_df = pd.DataFrame(dev_baseline)
test_dag_pos_df = pd.DataFrame(test_baseline)

#dev_cbg_marginals_df = pd.DataFrame(dev_baseline_marginals, columns=["marginals", "label"]).assign(num_lfs=0)
#test_cbg_marginals_df = pd.DataFrame(test_baseline_marginals, columns=["marginals", "label"]).assign(num_lfs=0)

pd.np.random.seed(100)
frequency = [0.25, 0.5, 0.75, 1]

for p_success in frequency:
    
    dev_random_grid = {}
    test_random_grid = {}
    
    for sample in tqdm_notebook(range(num_of_samples)):
        random_lf = pd.np.random.binomial(1, p_success, (correct_L.shape[0], 1))
        new_L = pd.np.concatenate([correct_L[:, ds_start:ds_end], random_lf], axis=1)

        random_lf = pd.np.random.binomial(1, p_success, (correct_L_dev.shape[0], 1))
        new_L_dev = pd.np.concatenate([correct_L_dev[:, ds_start:ds_end], random_lf], axis=1)

        random_lf = pd.np.random.binomial(1, p_success, (correct_L_test.shape[0], 1))
        new_L_test = pd.np.concatenate([correct_L_test[:, ds_start:ds_end], random_lf], axis=1)

        new_dev_grid, new_test_grid = train_baseline_model(
            new_L, new_L_dev, candidate_dfs['dev'].curated_dsh.values, 
            new_L_test, list(range(ds_start, ds_end+1)), regularization_grid,
            train_marginal_dir="results/DaG/marginals/"
        )
        dev_random_grid[sample] = new_dev_grid[list(new_dev_grid.keys())[0]]
        test_random_grid [sample] = new_test_grid[list(new_test_grid.keys())[0]]
    
    dev_dag_pos_df=(
        dev_dag_pos_df
        .append(
            generate_results_df(
                dev_random_grid, 
                candidate_dfs['dev'].curated_dsh.values
            )
            .rename(index=str, columns={0: "AUPRC", 1: "AUROC"})
            .assign(num_lfs=p_success),
            sort=False
        )
        .reset_index()
        .drop("index", axis=1)
    )
    
    test_dag_pos_df=(
        test_dag_pos_df
        .append(
            generate_results_df(
                test_random_grid, 
                candidate_dfs['test'].curated_dsh.values
            )
            .rename(index=str, columns={0: "AUPRC", 1: "AUROC"})
            .assign(num_lfs=p_success),
            sort=False
        )
        .reset_index()
        .drop("index", axis=1)
    )
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))

# %%
db_coverage = pd.Series(pd.np.any(new_L[:, ds_start:4], axis=1)).astype(int)
print(db_coverage.value_counts())
db_coverage.mean()

#absent_coverage = pd.Series(pd.np.any(new_L[:, 7:ds_end], axis=1)).astype(int)
#random_coverage = pd.Series(pd.np.any(new_L[:,9:10], axis=1)).astype(int)
#(absent_coverage+random_coverage).value_counts()
# Out:
# 0    336494
# 1    322109
# dtype: int64
# 0.4890791569428017

# %% [markdown]
# ## Dev Set Performance (AUPRC, AUROC)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10, 5))
sns.pointplot(x="num_lfs", y="AUPRC", data=dev_dag_pos_df, ax=axs[0])
sns.pointplot(x="num_lfs", y="AUROC", data=dev_dag_pos_df, ax=axs[1])
axs[1].set_ylim([0.5,1])
# Out:
# /home/danich1/anaconda2/envs/snorkeling/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0.5, 1)

# %% [markdown]
# ## Test Set Performance (AUPRC, AUROC)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10, 5))
sns.pointplot(x="num_lfs", y="AUPRC", data=test_dag_pos_df, ax=axs[0])
sns.pointplot(x="num_lfs", y="AUROC", data=test_dag_pos_df, ax=axs[1])
axs[1].set_ylim([0.5,1])
# Out:
# /home/danich1/anaconda2/envs/snorkeling/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0.5, 1)

# %%
dev_dag_pos_df.to_csv(
    "results/error_analysis/pos_random_lf_dev_performance.tsv", 
    index=False, sep="\t", float_format="%.5g"
)

test_dag_pos_df.to_csv(
    "results/error_analysis/pos_random_lf_test_performance.tsv", 
    index=False, sep="\t", float_format="%.5g"
)

# %% [markdown]
# # Random Label Function Negative Direction

# %% [markdown]
# This block is designed to determine how many label functions are needed to achieve decent results.

# %%
num_of_samples = 50
regularization_grid = pd.np.round(pd.np.linspace(0.01, 5, num=5), 2)

# %%
dev_dag_neg_df = pd.DataFrame(dev_baseline)
test_dag_neg_df = pd.DataFrame(test_baseline)

#dev_cbg_marginals_df = pd.DataFrame(dev_baseline_marginals, columns=["marginals", "label"]).assign(num_lfs=0)
#test_cbg_marginals_df = pd.DataFrame(test_baseline_marginals, columns=["marginals", "label"]).assign(num_lfs=0)

pd.np.random.seed(100)
frequency = [0.25, 0.5, 0.75, 1]

for p_success in frequency:
    
    dev_random_grid = {}
    test_random_grid = {}
    
    for sample in tqdm_notebook(range(num_of_samples)):
        random_lf = pd.np.random.binomial(1, p_success, (correct_L.shape[0], 1)) * 2
        new_L = pd.np.concatenate([correct_L[:, ds_start:ds_end], random_lf], axis=1)

        random_lf = pd.np.random.binomial(1, p_success, (correct_L_dev.shape[0], 1)) * 2
        new_L_dev = pd.np.concatenate([correct_L_dev[:, ds_start:ds_end], random_lf], axis=1)

        random_lf = pd.np.random.binomial(1, p_success, (correct_L_test.shape[0], 1)) * 2
        new_L_test = pd.np.concatenate([correct_L_test[:, ds_start:ds_end], random_lf], axis=1)

        new_dev_grid, new_test_grid = train_baseline_model(
            new_L, new_L_dev, candidate_dfs['dev'].curated_dsh.values, 
            new_L_test, list(range(ds_start, ds_end+1)), regularization_grid,
            train_marginal_dir="data/random_sampling/DaG/marginals/"
        )
        dev_random_grid[sample] = new_dev_grid[list(new_dev_grid.keys())[0]]
        test_random_grid [sample] = new_test_grid[list(new_test_grid.keys())[0]]
    
    dev_dag_neg_df=(
        dev_dag_neg_df
        .append(
            generate_results_df(
                dev_random_grid, 
                candidate_dfs['dev'].curated_dsh.values
            )
            .rename(index=str, columns={0: "AUPRC", 1: "AUROC"})
            .assign(num_lfs=p_success),
            sort=False
        )
        .reset_index()
        .drop("index", axis=1)
    )
    
    test_dag_neg_df=(
        test_dag_neg_df
        .append(
            generate_results_df(
                test_random_grid, 
                candidate_dfs['test'].curated_dsh.values
            )
            .rename(index=str, columns={0: "AUPRC", 1: "AUROC"})
            .assign(num_lfs=p_success),
            sort=False
        )
        .reset_index()
        .drop("index", axis=1)
    )
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))

# %% [markdown]
# ## Dev Set Performance (AUPRC, AUROC)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10, 5))
sns.pointplot(x="num_lfs", y="AUPRC", data=dev_dag_neg_df, ax=axs[0])
sns.pointplot(x="num_lfs", y="AUROC", data=dev_dag_neg_df, ax=axs[1])
axs[1].set_ylim([0.5,1])
# Out:
# /home/danich1/anaconda2/envs/snorkeling/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0.5, 1)

# %% [markdown]
# ## Test Set Performance (AUPRC, AUROC)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10, 5))
sns.pointplot(x="num_lfs", y="AUPRC", data=test_dag_neg_df, ax=axs[0])
sns.pointplot(x="num_lfs", y="AUROC", data=test_dag_neg_df, ax=axs[1])
axs[1].set_ylim([0.5,1])
# Out:
# /home/danich1/anaconda2/envs/snorkeling/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0.5, 1)

# %%
dev_dag_neg_df.to_csv(
    "results/error_analysis/neg_random_lf_dev_performance.tsv", 
    index=False, sep="\t", float_format="%.5g"
)

test_dag_neg_df.to_csv(
    "results/error_analysis/neg_random_lf_test_performance.tsv", 
    index=False, sep="\t", float_format="%.5g"
)
