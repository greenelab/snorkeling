# %%
import os
import pandas as pd
import sys
from tqdm import tqdm_notebook

sys.path.append(os.path.abspath('../../../modules'))

from utils.notebook_utils.dataframe_helper import mark_sentence

# %%
#Set up the environment
username = "danich1"
password = "snorkel"
dbname = "pubmeddb"

#Path subject to change for different os
database_str = "postgresql+psycopg2://{}:{}@/{}?host=/var/run/postgresql".format(username, password, dbname)
os.environ['SNORKELDB'] = database_str

from snorkel import SnorkelSession
session = SnorkelSession()

# %%
from snorkel.learning.pytorch.rnn.utils import candidate_to_tokens
from snorkel.models import Candidate, candidate_subclass

# %%
def get_edge_predictions(df):
    agg_df=(
        df
        .groupby(["source_node", "target_node"])
        .agg({"disc_model_prediction":["max", "idxmax"]})
        .reset_index()
    )
    agg_df.columns = [
        "_".join(col) 
        if col[1] != '' else col[0] 
        for col in agg_df.columns.values
    ]
    
    return (
        df
        .iloc[agg_df.disc_model_prediction_idxmax]
        .sort_values("disc_model_prediction", ascending=False)
    )

# %%
file_tree = {
    "DaG":
    {
        "gen_model": {
            "train":"../../../disease_gene/disease_associates_gene/label_sampling_experiment/results/DaG/marginals/train/30_sampled_train.tsv.xz",
            "tune":"../../../disease_gene/disease_associates_gene/label_sampling_experiment/results/DaG/marginals/tune/30_sampled_dev.tsv",
            "test":"../../../disease_gene/disease_associates_gene/label_sampling_experiment/results/DaG/marginals/test/30_sampled_test.tsv",
        },
        "disc_model": "../../../disease_gene/disease_associates_gene/edge_prediction_experiment/output/combined_predicted_dag_sentences.tsv.xz",
        "dataset_statistics":"../../../disease_gene/disease_associates_gene/dataset_statistics/results/all_dag_map.tsv.xz"
    },
    "CtD":
    {
        "gen_model": {
            "train":"../../../compound_disease/compound_treats_disease/label_sampling_experiment/results/CtD/marginals/train/22_sampled_train.tsv.xz",
            "tune":"../../../compound_disease/compound_treats_disease/label_sampling_experiment/results/CtD/marginals/tune/22_sampled_dev.tsv",
            "test":"../../../compound_disease/compound_treats_disease/label_sampling_experiment/results/CtD/marginals/test/22_sampled_test.tsv",
        },
        "disc_model": "../../../compound_disease/compound_treats_disease/edge_prediction_experiment/output/combined_predicted_ctd_sentences.tsv.xz",
        "dataset_statistics": "../../../compound_disease/compound_treats_disease/dataset_statistics/results/all_ctd_map.tsv.xz"
    },
    "CbG":
    {
        "gen_model": {
            "train":"../../../compound_gene/compound_binds_gene/label_sampling_experiment/results/CbG/marginals/train/20_sampled_train.tsv.xz",
            "tune":"../../../compound_gene/compound_binds_gene/label_sampling_experiment/results/CbG/marginals/tune/20_sampled_dev.tsv",
            "test":"../../../compound_gene/compound_binds_gene/label_sampling_experiment/results/CbG/marginals/test/20_sampled_test.tsv",
        },
        "disc_model": "../../../compound_gene/compound_binds_gene/edge_prediction_experiment/output/combined_predicted_cbg_sentences.tsv.xz",
        "dataset_statistics": "../../../compound_gene/compound_binds_gene/dataset_statistics/results/all_cbg_candidates.tsv.xz"
    },
    "GiG":
    {
        "gen_model": {
            "train":"../../../gene_gene/gene_interacts_gene/label_sampling_experiment/results/GiG/marginals/train/28_sampled_train.tsv.xz",
            "tune":"../../../gene_gene/gene_interacts_gene/label_sampling_experiment/results/GiG/marginals/tune/28_sampled_dev.tsv",
            "test":"../../../gene_gene/gene_interacts_gene/label_sampling_experiment/results/GiG/marginals/test/28_sampled_test.tsv"
        },
        "disc_model": "../../../gene_gene/gene_interacts_gene/edge_prediction_experiment/output/combined_predicted_gig_sentences.tsv.xz",
        "dataset_statistics":"../../../gene_gene/gene_interacts_gene/dataset_statistics/results/all_gig_candidates.tsv.xz"
    }
}

# %%
relation_data_dict = {}
for rel in file_tree:
    for model in file_tree[rel]:
        if model == "gen_model":
            gen_model = (
                pd.concat([
                    pd.read_csv(file_tree[rel][model][dataset], sep="\t").iloc[:,[0,-1]]
                    for dataset in file_tree[rel][model]
                ],
                    axis=0, 
                    ignore_index=True
                )
            )
            gen_model.columns = ["gen_model_prediction", "candidate_id"]
            
        elif model == "disc_model":
            disc_model = (
                pd.read_csv(file_tree[rel][model], sep="\t")
                .rename(index=str, columns={"model_prediction":"disc_model_prediction"})
            )
            
        else:
            data_stat = pd.read_csv(file_tree[rel][model], sep="\t")
            
    relation_data_dict[rel] = (
        disc_model
        .merge(gen_model, on="candidate_id")
        .merge(data_stat[["n_sentences", "candidate_id"]], on="candidate_id")
        .assign(edge_type=rel)
        .assign(hetionet=lambda x: x["hetionet"].apply(lambda y: "Existing" if y == 1 else "Novel"))
        .rename(index=str, columns={"pred":"disc_model_prediction"})
    )
# Out:
# /home/danich1/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (3,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/danich1/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
relation_data_dict["DaG"] = get_edge_predictions(
    relation_data_dict["DaG"]
    .drop(["doid_id", "entrez_gene_id"], axis=1)
    .rename(index=str, columns={
        "gene_symbol":"target_node",
        "doid_name":"source_node",
    })
)
relation_data_dict["DaG"].head(2)
# Out:
#            source_node target_node  \
# 144413    liver cancer        TP53
# 505433  stomach cancer        TP53
#
#                                                      text  hetionet  \
# 144413  CONCLUSION: The Ser-249 p53 mutation in plasma...  Existing
# 505433  CONCLUSION: This meta-analysis suggests that p...  Existing
#
#         candidate_id  split  disc_model_prediction  gen_model_prediction  \
# 144413       7082430      0               0.940527                   1.0
# 505433      25780904      0               0.937094                   1.0
#
#         n_sentences edge_type
# 144413         4467       DaG
# 505433         2679       DaG

# %%
relation_data_dict["CtD"] = get_edge_predictions(
    relation_data_dict["CtD"]
    .drop(["doid_id", "drugbank_id"], axis=1)
    .rename(index=str, columns={
        "doid_name":"target_node",
        "drug_name":"source_node",
    })
)
relation_data_dict["CtD"].head(2)
# Out:
#                  target_node   source_node  \
# 367686          liver cancer     Sorafenib
# 49443   rheumatoid arthritis  Methotrexate
#
#                                                      text  hetionet  \
# 367686  TACE plus sorafenib for the treatment of hepat...  Existing
# 49443   Comparison of low-dose oral pulse methotrexate...  Existing
#
#         candidate_id  split  disc_model_prediction  gen_model_prediction  \
# 367686      36358186      9               0.990262              0.999985
# 49443        2088538      9               0.989163              1.000000
#
#         n_sentences edge_type
# 367686         6672       CtD
# 49443         14546       CtD

# %%
relation_data_dict["CbG"] = get_edge_predictions(
    relation_data_dict["CbG"]
    .drop(["drugbank_id", "entrez_gene_id"], axis=1)
    .rename(index=str, columns={
        "gene_symbol":"target_node",
        "drug_name":"source_node",
    })
)
relation_data_dict["CbG"].head(2)
# Out:
#        source_node target_node  \
# 236597   Gefitinib        EGFR
# 270820   Adenosine        EGFR
#
#                                                      text  hetionet  \
# 236597  Morphologic features of adenocarcinoma of the ...  Existing
# 270820  It is well established that inhibiting ATP bin...     Novel
#
#         candidate_id  split  disc_model_prediction  gen_model_prediction  \
# 236597      19747145      6               0.989888              1.000000
# 270820      30301710      6               0.986698              0.999951
#
#         n_sentences edge_type
# 236597         8746       CbG
# 270820          644       CbG

# %%
relation_data_dict["GiG"] = get_edge_predictions(
    relation_data_dict["GiG"]
    .drop(["gene1_id", "gene2_id"], axis=1)
    .rename(index=str, columns={
        "gene2_name":"target_node",
        "gene1_name":"source_node",
    })
)
relation_data_dict["GiG"].head(2)
# Out:
#        source_node target_node  \
# 570392       BRCA2       BRCA1
# 265999        MDM2        TP53
#
#                                                      text  hetionet  \
# 570392  A total of 9 families (16%) showed mutations i...     Novel
# 265999  No mutations in the TP53 gene have been found ...  Existing
#
#         candidate_id  split  disc_model_prediction  gen_model_prediction  \
# 570392       6825347      3               0.984036              0.971842
# 265999       3231391      3               0.978062              0.937937
#
#         n_sentences edge_type
# 570392        12257       GiG
# 265999        17128       GiG

# %%
def tag_sentence(x, cand_class):
    candidates=(
        session
        .query(cand_class)
        .filter(cand_class.id.in_(x.candidate_id.astype(int).tolist()))
        .all()
    )
    tagged_sen=[
         " ".join(
             mark_sentence(
                candidate_to_tokens(cand), 
                [
                        (cand[0].get_word_start(), cand[0].get_word_end(), 1),
                        (cand[1].get_word_start(), cand[1].get_word_end(), 2)
                ]
            )
         )
        for cand in candidates
    ]

    return tagged_sen

# %%
DiseaseGene = candidate_subclass('DiseaseGene', ['Disease', 'Gene'])
CompoundDisease = candidate_subclass('CompoundDisease', ['Compound', 'Disease'])
CompoundGene = candidate_subclass('CompoundGene', ['Compound', 'Gene'])
GeneGene = candidate_subclass('GeneGene', ["Gene1", "Gene2"])

# %%
for rel in relation_data_dict:
    if rel == "DaG":
        relation_data_dict[rel] = (
            relation_data_dict[rel]
            .head(10)
            .sort_values("candidate_id")
            .assign(text=lambda x: tag_sentence(x, DiseaseGene))
            .sort_values("disc_model_prediction", ascending=False)
        )
    elif rel == "CtD":
        relation_data_dict[rel] = (
            relation_data_dict[rel]
            .head(10)
            .sort_values("candidate_id")
            .assign(text=lambda x: tag_sentence(x, CompoundDisease))
            .sort_values("disc_model_prediction", ascending=False)
        )
    elif rel == "CbG":
        relation_data_dict[rel] = (
            relation_data_dict[rel]
            .head(10)
            .sort_values("candidate_id")
            .assign(text=lambda x: tag_sentence(x, CompoundGene))
            .sort_values("disc_model_prediction", ascending=False)
        )
    else:
        relation_data_dict[rel] = (
            relation_data_dict[rel]
            .head(10)
            .sort_values("candidate_id")
            .assign(text=lambda x: tag_sentence(x, GeneGene))
            .sort_values("disc_model_prediction", ascending=False)
        )

# %%
total_table_df = pd.concat([
    relation_data_dict[rel] 
    for rel in relation_data_dict],
    axis=0, 
    ignore_index=True,
    sort=False
)
total_table_df
# Out:
#                source_node             target_node  \
# 0             liver cancer                    TP53
# 1           stomach cancer                    TP53
# 2              lung cancer                    TP53
# 3   urinary bladder cancer                    TP53
# 4           ovarian cancer                    EGFR
# 5        pancreatic cancer                    EGFR
# 6      Alzheimer's disease                   VEGFA
# 7            breast cancer                    TP53
# 8            breast cancer                    ESR1
# 9            breast cancer                    LEPR
# 10               Sorafenib            liver cancer
# 11            Methotrexate    rheumatoid arthritis
# 12               Auranofin    rheumatoid arthritis
# 13              Lamivudine             hepatitis B
# 14               Tamoxifen           breast cancer
# 15             Doxorubicin  urinary bladder cancer
# 16               Docetaxel           breast cancer
# 17              Cimetidine               psoriasis
# 18              Olanzapine           schizophrenia
# 19               Tamoxifen            liver cancer
# 20               Gefitinib                    EGFR
# 21               Adenosine                    EGFR
# 22           Rosiglitazone                   PPARG
# 23              D-Tyrosine                    INSR
# 24              D-Tyrosine                    IGF1
# 25                Pindolol                   HTR1A
# 26               Tamoxifen                    ESR1
# 27            Testosterone                      AR
# 28            Testosterone                    SHBG
# 29            Progesterone                    SHBG
# 30                   BRCA2                   BRCA1
# 31                    MDM2                    TP53
# 32                   BRCA1                   BRCA2
# 33                     SRY                     SRY
# 34                    TP53                    TP53
# 35                    KRAS                    TP53
# 36                      TF                      TF
# 37                    TP53                    HRAS
# 38                  IFNAR1                  IFNAR1
# 39                   ERBB2                   ERBB2
#
#                                                  text  hetionet  candidate_id  \
# 0   conclusion : the ser-249 ~~[[2 p53 2]]~~ mutat...  Existing       7082430
# 1   conclusion : this meta-analysis suggests that ...  Existing      25780904
# 2   conclusion : these results suggest that high e...  Existing       2882445
# 3   conclusion : this meta-analysis suggests that ...  Existing      26246704
# 4   conclusion : increased serum level of ~~[[2 eg...  Existing      28969837
# 5   conclusion : ~~[[2 egfr 2]]~~ expression is a ...  Existing      24873209
# 6   conclusion : serum ~~[[2 vegf 2]]~~ levels are...  Existing      34499985
# 7   conclusion : this data suggests that microvess...  Existing      16745504
# 8   conclusion : this finding confirms that the po...  Existing       8735705
# 9   conclusion : our results showed that the ~~[[2...  Existing      30796504
# 10  tace plus ~~[[1 sorafenib 1]]~~ for the treatm...  Existing      36358186
# 11  comparison of low-dose oral pulse ~~[[1 methot...  Existing       2088538
# 12  ~~[[1 auranofin 1]]~~ versus placebo in the tr...  Existing       2358985
# 13  randomized controlled trials ( rcts ) comparin...  Existing      28946965
# 14  long-term ~~[[1 tamoxifen 1]]~~ therapy for th...  Existing       7872103
# 15  17-year follow-up of a randomized prospective ...  Existing      14103239
# 16  currently , randomized phase iii trials have d...  Existing      16250597
# 17  ~~[[1 cimetidine 1]]~~ versus placebo in the t...     Novel       2420629
# 18  a double-blind , randomised comparative trial ...     Novel      10312446
# 19  high-dose ~~[[1 tamoxifen 1]]~~ in the treatme...     Novel      10312021
# 20  morphologic features of adenocarcinoma of the ...  Existing      19747145
# 21  it is well established that inhibiting ~~[[1 a...     Novel      30301710
# 22  ~~[[1 rosiglitazone 1]]~~ is a potent ~~[[2 pe...  Existing       7833510
# 23  this result suggests that ~~[[1 tyrosine 1]]~~...     Novel        861356
# 24  affinity-purified ~~[[2 insulin-like growth fa...     Novel       1799349
# 25  ~~[[1 pindolol 1]]~~ , a betablocker with weak...  Existing      14489761
# 26  ~~[[1 tamoxifen 1]]~~ is the first selective ~...  Existing       9471556
# 27  unlike the induction by ~~[[1 testosterone 1]]...  Existing        875495
# 28  all three forms of treatment resulted in relat...  Existing        112391
# 29  however , dng also elicits properties of ~~[[1...  Existing      20654829
# 30  a total of 9 families ( 16 % ) showed mutation...     Novel       6825347
# 31  no mutations in the ~~[[2 tp53 2]]~~ gene have...  Existing       3231391
# 32  pathogenic truncating mutations in the ~~[[1 b...  Existing      13349302
# 33  mutations in the ~~[[2 sry 2]]~~ gene have bee...     Novel      12044142
# 34  there was a strong correlation between missens...  Existing       4352905
# 35  mutations in the ~~[[2 p53 2]]~~ gene did not ...     Novel      23555024
# 36  almost 95 % of released ~~[[2 transferrin 2]]~...  Existing       1961217
# 37  pathologic examination of the uc specimens fro...     Novel      24647978
# 38  exhaustive genotyping of the interferon alpha ...     Novel      15501856
# 39  assays are available to detect the ~~[[2 her2 ...  Existing       8036873
#
#     split  disc_model_prediction  gen_model_prediction  n_sentences edge_type
# 0       0               0.940527              1.000000         4467       DaG
# 1       0               0.937094              1.000000         2679       DaG
# 2       0               0.936058              1.000000         6813       DaG
# 3       0               0.933189              1.000000         2112       DaG
# 4       0               0.931405              1.000000         1330       DaG
# 5       0               0.930334              1.000000         1119       DaG
# 6       0               0.930100              1.000000          350       DaG
# 7       0               0.928260              1.000000        10842       DaG
# 8       0               0.925765              1.000000        22975       DaG
# 9       0               0.924616              1.000000          265       DaG
# 10      9               0.990262              0.999985         6672       CtD
# 11      9               0.989163              1.000000        14546       CtD
# 12      9               0.988412              0.999985          419       CtD
# 13      9               0.988394              1.000000         6709       CtD
# 14      9               0.988341              0.999867        17804       CtD
# 15      9               0.988070              1.000000          930       CtD
# 16      9               0.987354              1.000000         5206       CtD
# 17      9               0.986989              0.998893           12       CtD
# 18      9               0.986865              1.000000         3324       CtD
# 19      9               0.986829              1.000000          404       CtD
# 20      6               0.989888              1.000000         8746       CbG
# 21      6               0.986698              0.999951          644       CbG
# 22      6               0.986666              1.000000         1498       CbG
# 23      6               0.986517              0.997810         1713       CbG
# 24      6               0.982546              0.997810          819       CbG
# 25      6               0.982540              1.000000          175       CbG
# 26      6               0.982500              1.000000         3653       CbG
# 27      6               0.981898              1.000000         1083       CbG
# 28      6               0.981065              0.999970         7533       CbG
# 29      6               0.981010              0.999986          492       CbG
# 30      3               0.984036              0.971842        12257       GiG
# 31      3               0.978062              0.937937        17128       GiG
# 32      3               0.977530              0.999995        12257       GiG
# 33      3               0.975986              0.124124         1618       GiG
# 34      3               0.973703              0.999996       119624       GiG
# 35      3               0.971495              0.992161         4106       GiG
# 36      3               0.970288              0.999979        12006       GiG
# 37      3               0.968956              0.992161          451       GiG
# 38      3               0.967967              0.978169          528       GiG
# 39      3               0.967304              0.999998        69020       GiG

# %%
(
    total_table_df
    [[
        "edge_type",
        "source_node", "target_node", 
        "hetionet",
        "gen_model_prediction", "disc_model_prediction",
        "n_sentences", "text"
    ]]
    .to_csv("../generative_model_predictions.tsv", sep='\t', index=False, float_format='%.3f')
)
