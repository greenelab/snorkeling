# %% [markdown]
# # Using Labels from Different Relation Types to Predict Compound Binds Gene Sentences

# %% [markdown]
# This notebook is designed to predict the compound binds gene (CbG) relation. The first step in this process is to label our train, dev, and test sentences (split = 6,7,8). We will label these sentences using all of our handcrafted label functions. The working hypothesis here is there are shared information between different relations, which in turn should aid in predicting the compound binds gene relation. After the labeling process, the next step is to train a generative model that will estimate the likelihood of the positive class ($\hat{Y}$) given our annotated label matrix. **Note**: This process doesn't involve any sentence context, so the only information used here are categorical output.

# %% [markdown]
# ## Set up the environment

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from collections import defaultdict
import os
import pickle
import sys

sys.path.append(os.path.abspath('../../../modules'))

# Bayesian Optimization
from hyperopt import fmin, hp, tpe, Trials

from itertools import chain
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import sparse
from sklearn.metrics import roc_curve, auc, f1_score, precision_recall_curve, accuracy_score
from tqdm import tqdm_notebook

# %%
#Set up the environment
username = "danich1"
password = "snorkel"
dbname = "pubmeddb"

#Path subject to change for different os
database_str = "postgresql+psycopg2://{}:{}@/{}?host=/var/run/postgresql".format(username, password, dbname)
os.environ['SNORKELDB'] = database_str

from snorkel import SnorkelSession
session = SnorkelSession()

# %%
from snorkel.learning.pytorch.rnn.rnn_base import mark_sentence
from snorkel.learning.pytorch.rnn.utils import candidate_to_tokens
from snorkel.models import Candidate, candidate_subclass

from metal.analysis import lf_summary
from metal.label_model import LabelModel
from metal.utils import plusminus_to_categorical

from gensim.models import FastText
from gensim.models import KeyedVectors

from utils.notebook_utils.label_matrix_helper import label_candidates, get_auc_significant_stats
from utils.notebook_utils.dataframe_helper import load_candidate_dataframes, generate_results_df
from utils.notebook_utils.plot_helper import plot_curve, plot_label_matrix_heatmap
from utils.notebook_utils.train_model_helper import (
    train_baseline_model,
    run_random_additional_lfs
)

sys.path.append(os.path.abspath('../data/label_functions'))
sys.path.append(os.path.abspath('../../../disease_gene/disease_associates_gene/data/label_functions'))
sys.path.append(os.path.abspath('../../../compound_disease/compound_treats_disease/data/label_functions'))
sys.path.append(os.path.abspath('../../../compound_gene/compound_binds_gene/data/label_functions'))
from compound_gene_lf import CG_LFS
from disease_gene_lfs import DG_LFS
from compound_disease_lf import CD_LFS
from gene_gene_lf import GG_LFS
# Out:
# /home/danich1/anaconda2/envs/snorkeling/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2903: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
GeneGene = candidate_subclass('GeneGene', ['Gene1', 'Gene2'])

# %%
quick_load = True

# %% [markdown]
# ## Load the Data and Label the  Sentences

# %% [markdown]
# This block of code is designed to label the sentences using our label functions. All the sentences are located in our postgres database that is store locally on the lab machine. The labeling process is defined as follows: Given a candidate id, we use the sqlalchemy library to extract a candidate object. Using this object and we pass it through a series of label functions that will output a 1 (positive), -1 (negative) or 0 (abstain) depending on the rule set. Lastly we aggregate the output of these functions into a sparse matrix that the generative model will use. Since these steps are pretty linear, we parallelized this process using python's multithreading library. Despite the optimization, this process can still take about 3 hours to label a set of ~300000 sentences.

# %%
total_candidates_df = pd.read_table("../dataset_statistics/results/all_gig_candidates.tsv.xz")
total_candidates_df.head(2)
# Out:
# /home/danich1/anaconda2/envs/snorkeling/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    gene1_id gene1_name  gene2_id gene2_name                  sources  \
# 0         1       A1BG     10321     CRISP3  II_literature|hetio-dag
# 1         1       A1BG     10321     CRISP3  II_literature|hetio-dag
#
#    n_sentences  hetionet  has_sentence  split  partition_rank  \
# 0            5         1             1      3        0.436432
# 1            5         1             1      3        0.436432
#
#    compound_mention_count  disease_mention_count  gene_mention_count  \
# 0                     0.0                    0.0                   2
# 1                     0.0                    0.0                   3
#
#    sentence_id                                               text  sen_length  \
# 0     65570963  Human CRISP-3 binds serum alpha(1)B-glycoprote...          11
# 1     65570968  BACKGROUND: CRISP-3 was previously shown to be...          21
#
#    candidate_id
# 0      20992573
# 1      20930188

# %%
spreadsheet_names = {
    #'train': 'data/sentences/sentence_labels_train.xlsx',
    'dev': '../data/sentences/sentence_labels_dev.xlsx',
    'test': '../data/sentences/sentence_labels_test.xlsx'
}

# %%
candidate_dfs = {
    key:load_candidate_dataframes(spreadsheet_names[key], "curated_gig")
    for key in spreadsheet_names
}

for key in candidate_dfs:
    print("Size of {} set: {}".format(key, candidate_dfs[key].shape[0]))
# Out:
# Size of dev set: 500
# Size of test set: 500

# %%
lfs = (
    list(CG_LFS["CbG"].values()) + 
    list(DG_LFS["DaG"].values())[7:37] + 
    list(CD_LFS["CtD"].values())[3:25] + 
    list(GG_LFS["GiG"].values())[9:37]
)
lf_names = (
    list(CG_LFS["CbG"].keys()) + 
    list(DG_LFS["DaG"].keys())[7:37] + 
    list(CD_LFS["CtD"].keys())[3:25] + 
    list(GG_LFS["GiG"].keys())[9:37]
)

# %%
if not quick_load:
    label_matricies = {
        'train':label_candidates(
            session, 
            (
                total_candidates_df
                .query("split==3&gene_mention_count==2")
                .candidate_id
                .values
                .tolist()
            ),
            lfs, 
            lf_names,
            num_threads=10,
            batch_size=50000,
            multitask=False
        )
    }

# %%
if not quick_load:
    label_matricies.update({
        key:label_candidates(
            session, 
            candidate_dfs[key]['candidate_id'].values.tolist(),
            lfs, 
            lf_names,
            num_threads=10,
            batch_size=50000,
            multitask=False
        )
        for key in candidate_dfs
    })

# %%
# Save the label matricies to a file for future loading/error analysis
if not quick_load:
    (
        label_matricies['train']
        .sort_values("candidate_id")
        .to_csv("../data/label_matricies/train_sparse_matrix.tsv.xz", sep="\t", index=False)
    )
    (
        label_matricies['dev']
        .sort_values("candidate_id")
        .to_csv("../data/label_matricies/dev_sparse_matrix.tsv.xz", sep="\t", index=False)
    )
    (
        label_matricies['test']
        .sort_values("candidate_id")
        .to_csv("../data/label_matricies/test_sparse_matrix.tsv.xz", sep="\t", index=False)
    )
# Quick load the label matricies
else:
    label_destinations = {
        'train':"../data/label_matricies/train_sparse_matrix.tsv.xz",
        'dev':"../data/label_matricies/dev_sparse_matrix.tsv.xz",
        'test':"../data/label_matricies/test_sparse_matrix.tsv.xz"
    }
    label_matricies = {
        key:pd.read_table(label_destinations[key]).to_sparse()
        for key in label_destinations
    }

# %%
# Important Note Snorkel Metal uses a different coding scheme
# than the label functions output. (2 for negative instead of -1).
# This step corrects this problem by converting -1s to 2

correct_L = plusminus_to_categorical(
    label_matricies['train']
    .sort_values("candidate_id")
    .drop("candidate_id", axis=1)
    .to_coo()
    .toarray()
    .astype(int)
)

correct_L_dev = plusminus_to_categorical(
    label_matricies['dev']
    .sort_values("candidate_id")
    .drop("candidate_id", axis=1)
    .to_coo()
    .toarray()
    .astype(int)
)

correct_L_test = plusminus_to_categorical(
    label_matricies['test']
    .sort_values("candidate_id")
    .drop("candidate_id", axis=1)
    .to_coo()
    .toarray()
    .astype(int)
)

# %%
lf_summary(
    sparse.coo_matrix(
        correct_L
    )
    .tocsr(), 
    lf_names=lf_names
)
# Out:
#                                         j Polarity  Coverage  Overlaps  \
# LF_HETNET_DRUGBANK                      0        1  0.004701  0.004701
# LF_HETNET_DRUGCENTRAL                   1        1  0.000104  0.000104
# LF_HETNET_ChEMBL                        2        1  0.000847  0.000847
# LF_HETNET_BINDINGDB                     3        1  0.013369  0.013369
# LF_HETNET_PDSP_KI                       4        1  0.195569  0.195569
# LF_HETNET_US_PATENT                     5       []  0.000000  0.000000
# LF_HETNET_PUBCHEM                       6       []  0.000000  0.000000
# LF_HETNET_CG_ABSENT                     7        1  0.107414  0.107414
# LF_CG_CHECK_GENE_TAG                    8        2  0.741340  0.741340
# LF_CG_BINDING                           9        1  0.053853  0.053853
# LF_CG_WEAK_BINDING                     10        2  0.394562  0.394562
# LF_CG_GENE_RECEIVERS                   11        2  0.015190  0.015190
# LF_CG_ASE_SUFFIX                       12        2  0.012390  0.012390
# LF_CG_IN_SERIES                        13        2  0.009711  0.009711
# LF_CG_ANTIBODY                         14        2  0.024264  0.024264
# LF_CG_METHOD_DESC                      15        2  0.018389  0.018389
# LF_CG_NO_CONCLUSION                    16        1  0.073223  0.073223
# LF_CG_CONCLUSION                       17        1  0.124285  0.124285
# LF_CG_DISTANCE_SHORT                   18        2  0.009042  0.009042
# LF_CG_DISTANCE_LONG                    19        2  0.000489  0.000489
# LF_CG_ALLOWED_DISTANCE                 20        2  0.016240  0.016240
# LF_CG_NO_VERB                          21        2  0.175252  0.175252
# LF_CG_BICLUSTER_BINDS                  22        2  0.110949  0.110949
# LF_CG_BICLUSTER_AGONISM                23        2  0.869877  0.869877
# LF_CG_BICLUSTER_ANTAGONISM             24   [1, 2]  0.130123  0.130123
# LF_CG_BICLUSTER_INC_EXPRESSION         25        2  0.359408  0.359408
# LF_CG_BICLUSTER_DEC_EXPRESSION         26        2  0.039565  0.039565
# LF_CG_BICLUSTER_AFF_EXPRESSION         27        1  0.601027  0.601027
# LF_CG_BICLUSTER_INHIBITS               28        2  0.045944  0.045944
# LF_DG_IS_BIOMARKER                     29        1  0.098012  0.098012
# ...                                   ...      ...       ...       ...
# LF_CD_BICLUSTER_DISEASE_ROLE           79        2  0.039565  0.039565
# LF_CD_BICLUSTER_BIOMARKERS             80        1  0.541899  0.541899
# LF_GiG_BINDING_IDENTIFICATIONS         81        2  0.044014  0.044014
# LF_GiG_CELL_IDENTIFICATIONS            82        1  0.012848  0.012848
# LF_GiG_COMPOUND_IDENTIFICATIONS        83        1  0.011559  0.011559
# LF_GiG_UPREGULATES                     84        2  0.011101  0.011101
# LF_GiG_DOWNREGULATES                   85        1  0.011398  0.011398
# LF_GiG_REGULATION                      86        2  0.010110  0.010110
# LF_GiG_ASSOCIATION                     87        1  0.011135  0.011135
# LF_GiG_BOUND_IDENTIFIERS               88        1  0.008432  0.008432
# LF_GiG_GENE_IDENTIFIERS                89        1  0.048624  0.048624
# LF_GiG_GENE_ADJECTIVE                  90        1  0.005102  0.005102
# LF_GiG_DIAGNOSIS_IDENTIFIERS           91        1  0.086348  0.086348
# LF_GiG_METHOD_DESC                     92        1  0.033861  0.033861
# LF_GiG_PARENTHESIS                     93        2  0.110949  0.110949
# LF_GG_IN_SERIES                        94        1  0.006028  0.006028
# LF_GiG_NO_CONCLUSION                   95        2  0.102351  0.102351
# LF_GiG_CONCLUSION                      96        2  0.809485  0.809485
# LF_GG_DISTANCE_SHORT                   97        1  0.190515  0.190515
# LF_GG_DISTANCE_LONG                    98        2  0.418536  0.418536
# LF_GG_ALLOWED_DISTANCE                 99        2  0.039565  0.039565
# LF_GG_NO_VERB                         100        1  0.352256  0.352256
# LF_GG_BICLUSTER_BINDING               101        2  0.044014  0.044014
# LF_GG_BICLUSTER_ENHANCES              102        1  0.031587  0.031587
# LF_GG_BICLUSTER_ACTIVATES             103        1  0.018068  0.018068
# LF_GG_BICLUSTER_AFFECTS_EXPRESSION    104        1  0.015022  0.015022
# LF_GG_BICLUSTER_INCREASES_EXPRESSION  105        1  0.026702  0.026702
# LF_GG_BICLUSTER_SIGNALING             106        1  0.030932  0.030932
# LF_GG_BICLUSTER_IDENTICAL_PROTEIN     107        1  0.049675  0.049675
# LF_GG_BICLUSTER_CELL_PRODUCTION       108        1  0.025380  0.025380
#
#                                       Conflicts
# LF_HETNET_DRUGBANK                     0.004700
# LF_HETNET_DRUGCENTRAL                  0.000104
# LF_HETNET_ChEMBL                       0.000847
# LF_HETNET_BINDINGDB                    0.013368
# LF_HETNET_PDSP_KI                      0.195541
# LF_HETNET_US_PATENT                    0.000000
# LF_HETNET_PUBCHEM                      0.000000
# LF_HETNET_CG_ABSENT                    0.107401
# LF_CG_CHECK_GENE_TAG                   0.678971
# LF_CG_BINDING                          0.053836
# LF_CG_WEAK_BINDING                     0.368348
# LF_CG_GENE_RECEIVERS                   0.014983
# LF_CG_ASE_SUFFIX                       0.012274
# LF_CG_IN_SERIES                        0.009600
# LF_CG_ANTIBODY                         0.024024
# LF_CG_METHOD_DESC                      0.018273
# LF_CG_NO_CONCLUSION                    0.073213
# LF_CG_CONCLUSION                       0.124273
# LF_CG_DISTANCE_SHORT                   0.008821
# LF_CG_DISTANCE_LONG                    0.000489
# LF_CG_ALLOWED_DISTANCE                 0.015125
# LF_CG_NO_VERB                          0.150485
# LF_CG_BICLUSTER_BINDS                  0.104086
# LF_CG_BICLUSTER_AGONISM                0.807575
# LF_CG_BICLUSTER_ANTAGONISM             0.130021
# LF_CG_BICLUSTER_INC_EXPRESSION         0.297455
# LF_CG_BICLUSTER_DEC_EXPRESSION         0.039150
# LF_CG_BICLUSTER_AFF_EXPRESSION         0.600991
# LF_CG_BICLUSTER_INHIBITS               0.042103
# LF_DG_IS_BIOMARKER                     0.098012
# ...                                         ...
# LF_CD_BICLUSTER_DISEASE_ROLE           0.039150
# LF_CD_BICLUSTER_BIOMARKERS             0.541863
# LF_GiG_BINDING_IDENTIFICATIONS         0.040483
# LF_GiG_CELL_IDENTIFICATIONS            0.012848
# LF_GiG_COMPOUND_IDENTIFICATIONS        0.011559
# LF_GiG_UPREGULATES                     0.011082
# LF_GiG_DOWNREGULATES                   0.011398
# LF_GiG_REGULATION                      0.010097
# LF_GiG_ASSOCIATION                     0.011135
# LF_GiG_BOUND_IDENTIFIERS               0.008432
# LF_GiG_GENE_IDENTIFIERS                0.048607
# LF_GiG_GENE_ADJECTIVE                  0.005101
# LF_GiG_DIAGNOSIS_IDENTIFIERS           0.086331
# LF_GiG_METHOD_DESC                     0.033860
# LF_GiG_PARENTHESIS                     0.104086
# LF_GG_IN_SERIES                        0.006027
# LF_GiG_NO_CONCLUSION                   0.095758
# LF_GiG_CONCLUSION                      0.747117
# LF_GG_DISTANCE_SHORT                   0.190479
# LF_GG_DISTANCE_LONG                    0.356583
# LF_GG_ALLOWED_DISTANCE                 0.039150
# LF_GG_NO_VERB                          0.352232
# LF_GG_BICLUSTER_BINDING                0.040483
# LF_GG_BICLUSTER_ENHANCES               0.031586
# LF_GG_BICLUSTER_ACTIVATES              0.018067
# LF_GG_BICLUSTER_AFFECTS_EXPRESSION     0.015022
# LF_GG_BICLUSTER_INCREASES_EXPRESSION   0.026700
# LF_GG_BICLUSTER_SIGNALING              0.030931
# LF_GG_BICLUSTER_IDENTICAL_PROTEIN      0.049673
# LF_GG_BICLUSTER_CELL_PRODUCTION        0.025379
#
# [109 rows x 5 columns]

# %%
lf_summary(
    sparse.coo_matrix(
        correct_L_dev
    )
    .tocsr(), 
    lf_names=lf_names, 
    Y=candidate_dfs['dev'].curated_gig.apply(lambda x: 1 if x> 0 else 2)
)
# Out:
# /home/danich1/Documents/metal/metal/analysis.py:131: RuntimeWarning: invalid value encountered in true_divide
#   return 0.5 * (X.sum(axis=0) / (L != 0).sum(axis=0) + 1)
#                                         j Polarity  Coverage  Overlaps  \
# LF_HETNET_DRUGBANK                      0        1     0.002     0.002
# LF_HETNET_DRUGCENTRAL                   1       []     0.000     0.000
# LF_HETNET_ChEMBL                        2        1     0.002     0.002
# LF_HETNET_BINDINGDB                     3        1     0.006     0.006
# LF_HETNET_PDSP_KI                       4        1     0.138     0.138
# LF_HETNET_US_PATENT                     5       []     0.000     0.000
# LF_HETNET_PUBCHEM                       6       []     0.000     0.000
# LF_HETNET_CG_ABSENT                     7        1     0.292     0.292
# LF_CG_CHECK_GENE_TAG                    8        2     0.706     0.706
# LF_CG_BINDING                           9        1     0.182     0.182
# LF_CG_WEAK_BINDING                     10        2     0.484     0.484
# LF_CG_GENE_RECEIVERS                   11        2     0.002     0.002
# LF_CG_ASE_SUFFIX                       12        2     0.012     0.012
# LF_CG_IN_SERIES                        13        2     0.012     0.012
# LF_CG_ANTIBODY                         14        2     0.028     0.028
# LF_CG_METHOD_DESC                      15        2     0.022     0.022
# LF_CG_NO_CONCLUSION                    16        1     0.098     0.098
# LF_CG_CONCLUSION                       17        1     0.088     0.088
# LF_CG_DISTANCE_SHORT                   18        2     0.014     0.014
# LF_CG_DISTANCE_LONG                    19       []     0.000     0.000
# LF_CG_ALLOWED_DISTANCE                 20        2     0.010     0.010
# LF_CG_NO_VERB                          21        2     0.026     0.026
# LF_CG_BICLUSTER_BINDS                  22        2     0.210     0.210
# LF_CG_BICLUSTER_AGONISM                23        2     0.808     0.808
# LF_CG_BICLUSTER_ANTAGONISM             24   [1, 2]     0.192     0.192
# LF_CG_BICLUSTER_INC_EXPRESSION         25        2     0.266     0.266
# LF_CG_BICLUSTER_DEC_EXPRESSION         26        2     0.006     0.006
# LF_CG_BICLUSTER_AFF_EXPRESSION         27        1     0.728     0.728
# LF_CG_BICLUSTER_INHIBITS               28        2     0.034     0.034
# LF_DG_IS_BIOMARKER                     29        1     0.306     0.306
# ...                                   ...      ...       ...       ...
# LF_CD_BICLUSTER_DISEASE_ROLE           79        2     0.006     0.006
# LF_CD_BICLUSTER_BIOMARKERS             80        1     0.640     0.640
# LF_GiG_BINDING_IDENTIFICATIONS         81        2     0.048     0.048
# LF_GiG_CELL_IDENTIFICATIONS            82       []     0.000     0.000
# LF_GiG_COMPOUND_IDENTIFICATIONS        83       []     0.000     0.000
# LF_GiG_UPREGULATES                     84       []     0.000     0.000
# LF_GiG_DOWNREGULATES                   85       []     0.000     0.000
# LF_GiG_REGULATION                      86       []     0.000     0.000
# LF_GiG_ASSOCIATION                     87       []     0.000     0.000
# LF_GiG_BOUND_IDENTIFIERS               88       []     0.000     0.000
# LF_GiG_GENE_IDENTIFIERS                89        1     0.132     0.132
# LF_GiG_GENE_ADJECTIVE                  90        1     0.006     0.006
# LF_GiG_DIAGNOSIS_IDENTIFIERS           91        1     0.118     0.118
# LF_GiG_METHOD_DESC                     92        1     0.022     0.022
# LF_GiG_PARENTHESIS                     93        2     0.210     0.210
# LF_GG_IN_SERIES                        94       []     0.000     0.000
# LF_GiG_NO_CONCLUSION                   95        2     0.052     0.052
# LF_GiG_CONCLUSION                      96        2     0.742     0.742
# LF_GG_DISTANCE_SHORT                   97        1     0.258     0.258
# LF_GG_DISTANCE_LONG                    98        2     0.354     0.354
# LF_GG_ALLOWED_DISTANCE                 99        2     0.006     0.006
# LF_GG_NO_VERB                         100        1     0.400     0.400
# LF_GG_BICLUSTER_BINDING               101        2     0.048     0.048
# LF_GG_BICLUSTER_ENHANCES              102        1     0.030     0.030
# LF_GG_BICLUSTER_ACTIVATES             103        1     0.016     0.016
# LF_GG_BICLUSTER_AFFECTS_EXPRESSION    104        1     0.014     0.014
# LF_GG_BICLUSTER_INCREASES_EXPRESSION  105        1     0.022     0.022
# LF_GG_BICLUSTER_SIGNALING             106        1     0.030     0.030
# LF_GG_BICLUSTER_IDENTICAL_PROTEIN     107        1     0.044     0.044
# LF_GG_BICLUSTER_CELL_PRODUCTION       108        1     0.018     0.018
#
#                                       Conflicts  Correct  Incorrect  Emp. Acc.
# LF_HETNET_DRUGBANK                        0.002        0          1   0.000000
# LF_HETNET_DRUGCENTRAL                     0.000        0          0        NaN
# LF_HETNET_ChEMBL                          0.002        0          1   0.000000
# LF_HETNET_BINDINGDB                       0.006        0          3   0.000000
# LF_HETNET_PDSP_KI                         0.138       20         49   0.289855
# LF_HETNET_US_PATENT                       0.000        0          0        NaN
# LF_HETNET_PUBCHEM                         0.000        0          0        NaN
# LF_HETNET_CG_ABSENT                       0.292       35        111   0.239726
# LF_CG_CHECK_GENE_TAG                      0.654      328         25   0.929178
# LF_CG_BINDING                             0.182       42         49   0.461538
# LF_CG_WEAK_BINDING                        0.456      217         25   0.896694
# LF_CG_GENE_RECEIVERS                      0.002        1          0   1.000000
# LF_CG_ASE_SUFFIX                          0.012        5          1   0.833333
# LF_CG_IN_SERIES                           0.012        5          1   0.833333
# LF_CG_ANTIBODY                            0.028       12          2   0.857143
# LF_CG_METHOD_DESC                         0.022       10          1   0.909091
# LF_CG_NO_CONCLUSION                       0.098       13         36   0.265306
# LF_CG_CONCLUSION                          0.088        2         42   0.045455
# LF_CG_DISTANCE_SHORT                      0.014        7          0   1.000000
# LF_CG_DISTANCE_LONG                       0.000        0          0        NaN
# LF_CG_ALLOWED_DISTANCE                    0.010        4          1   0.800000
# LF_CG_NO_VERB                             0.026       13          0   1.000000
# LF_CG_BICLUSTER_BINDS                     0.194       99          6   0.942857
# LF_CG_BICLUSTER_AGONISM                   0.756      375         29   0.928218
# LF_CG_BICLUSTER_ANTAGONISM                0.192       36         60   0.375000
# LF_CG_BICLUSTER_INC_EXPRESSION            0.214      122         11   0.917293
# LF_CG_BICLUSTER_DEC_EXPRESSION            0.006        3          0   1.000000
# LF_CG_BICLUSTER_AFF_EXPRESSION            0.728       49        315   0.134615
# LF_CG_BICLUSTER_INHIBITS                  0.026       17          0   1.000000
# LF_DG_IS_BIOMARKER                        0.306       25        128   0.163399
# ...                                         ...      ...        ...        ...
# LF_CD_BICLUSTER_DISEASE_ROLE              0.006        3          0   1.000000
# LF_CD_BICLUSTER_BIOMARKERS                0.640       36        284   0.112500
# LF_GiG_BINDING_IDENTIFICATIONS            0.046       20          4   0.833333
# LF_GiG_CELL_IDENTIFICATIONS               0.000        0          0        NaN
# LF_GiG_COMPOUND_IDENTIFICATIONS           0.000        0          0        NaN
# LF_GiG_UPREGULATES                        0.000        0          0        NaN
# LF_GiG_DOWNREGULATES                      0.000        0          0        NaN
# LF_GiG_REGULATION                         0.000        0          0        NaN
# LF_GiG_ASSOCIATION                        0.000        0          0        NaN
# LF_GiG_BOUND_IDENTIFIERS                  0.000        0          0        NaN
# LF_GiG_GENE_IDENTIFIERS                   0.132       29         37   0.439394
# LF_GiG_GENE_ADJECTIVE                     0.006        0          3   0.000000
# LF_GiG_DIAGNOSIS_IDENTIFIERS              0.118       13         46   0.220339
# LF_GiG_METHOD_DESC                        0.022        0         11   0.000000
# LF_GiG_PARENTHESIS                        0.194       99          6   0.942857
# LF_GG_IN_SERIES                           0.000        0          0        NaN
# LF_GiG_NO_CONCLUSION                      0.044       25          1   0.961538
# LF_GiG_CONCLUSION                         0.690      346         25   0.932615
# LF_GG_DISTANCE_SHORT                      0.258       35         94   0.271318
# LF_GG_DISTANCE_LONG                       0.302      153         24   0.864407
# LF_GG_ALLOWED_DISTANCE                    0.006        3          0   1.000000
# LF_GG_NO_VERB                             0.400       22        178   0.110000
# LF_GG_BICLUSTER_BINDING                   0.046       20          4   0.833333
# LF_GG_BICLUSTER_ENHANCES                  0.030        3         12   0.200000
# LF_GG_BICLUSTER_ACTIVATES                 0.016        1          7   0.125000
# LF_GG_BICLUSTER_AFFECTS_EXPRESSION        0.014        1          6   0.142857
# LF_GG_BICLUSTER_INCREASES_EXPRESSION      0.022        1         10   0.090909
# LF_GG_BICLUSTER_SIGNALING                 0.030        2         13   0.133333
# LF_GG_BICLUSTER_IDENTICAL_PROTEIN         0.044        4         18   0.181818
# LF_GG_BICLUSTER_CELL_PRODUCTION           0.018        1          8   0.111111
#
# [109 rows x 8 columns]

# %% [markdown]
# # Train Baseline Model

# %% [markdown]
# This block trains the baseline model (Distant Supervision of CbG Databases) that will be used as a reference to compare against.

# %%
ds_start = 0
ds_end = 9
regularization_grid = pd.np.round(pd.np.linspace(0.01, 5, num=5), 2)

# %%
dev_ds_grid, test_ds_grid = train_baseline_model(
    correct_L, correct_L_dev, candidate_dfs['dev'].curated_gig.values,
    correct_L_test, list(range(ds_start, ds_end)), regularization_grid,
    train_marginal_dir="data/random_sampling/GiG/marginals/"
)

dev_baseline_marginals = list(dev_ds_grid.values())[0][:,0]
test_baseline_marginals = list(test_ds_grid.values())[0][:,0]

dev_ds_grid = (
    generate_results_df(
        dev_ds_grid, 
        candidate_dfs['dev'].curated_gig.values
    )
    .reset_index()
    .rename(index=str, columns={0:"AUPRC", 1:"AUROC", "index":"l2_param"})
)

test_ds_grid = (
    generate_results_df(
        test_ds_grid, 
        candidate_dfs['test'].curated_gig.values
    )
    .reset_index()
    .rename(index=str, columns={0:"AUPRC", 1:"AUROC", "index":"l2_param"})
)

# %%
best_param = dev_ds_grid.query("AUROC==AUROC.max()").l2_param.values[0]
dev_baseline=dev_ds_grid.query("l2_param==@best_param").to_dict('records')
dev_baseline[0].update({"num_lfs": 0})

# %%
test_baseline=test_ds_grid.query("l2_param==@best_param").to_dict('records')
test_baseline[0].update({"num_lfs": 0})

# %%
dev_baseline_marginals = list(zip(dev_baseline_marginals, candidate_dfs['dev'].curated_gig.values))
test_baseline_marginals = list(zip(test_baseline_marginals, candidate_dfs['test'].curated_gig.values))

# %%
count_fraction_correct = lambda x: 1 if (x.marginals > 0.5 and x.label==1) or (x.marginals < 0.5 and x.label==0) else 0

# %% [markdown]
# # Random Label Function Positive Direction

# %% [markdown]
# This block is designed to determine how many label functions are needed to achieve decent results.

# %%
num_of_samples = 50
regularization_grid = pd.np.round(pd.np.linspace(0.01, 5, num=5), 2)

# %%
dev_gig_pos_df = pd.DataFrame(dev_baseline)
test_gig_pos_df = pd.DataFrame(test_baseline)

pd.np.random.seed(100)
frequency = [0.25, 0.5, 0.75, 1]

for p_success in frequency:
    
    dev_random_grid = {}
    test_random_grid = {}
    
    for sample in tqdm_notebook(range(num_of_samples)):
        random_lf = pd.np.random.binomial(1, p_success, (correct_L.shape[0], 1))
        new_L = pd.np.concatenate([correct_L[:, ds_start:ds_end], random_lf], axis=1)

        random_lf = pd.np.random.binomial(1, p_success, (correct_L_dev.shape[0], 1))
        new_L_dev = pd.np.concatenate([correct_L_dev[:, ds_start:ds_end], random_lf], axis=1)

        random_lf = pd.np.random.binomial(1, p_success, (correct_L_test.shape[0], 1))
        new_L_test = pd.np.concatenate([correct_L_test[:, ds_start:ds_end], random_lf], axis=1)

        new_dev_grid, new_test_grid = train_baseline_model(
            new_L, new_L_dev, candidate_dfs['dev'].curated_gig.values, 
            new_L_test, list(range(ds_start, ds_end+1)), regularization_grid,
            train_marginal_dir="data/random_sampling/GiG/marginals/"
        )
        dev_random_grid[sample] = new_dev_grid[list(new_dev_grid.keys())[0]]
        test_random_grid [sample] = new_test_grid[list(new_test_grid.keys())[0]]
    
    dev_gig_pos_df=(
        dev_gig_pos_df
        .append(
            generate_results_df(
                dev_random_grid, 
                candidate_dfs['dev'].curated_gig.values
            )
            .rename(index=str, columns={0: "AUPRC", 1: "AUROC"})
            .assign(num_lfs=p_success),
            sort=False
        )
        .reset_index()
        .drop("index", axis=1)
    )
    
    test_gig_pos_df=(
        test_gig_pos_df
        .append(
            generate_results_df(
                test_random_grid, 
                candidate_dfs['test'].curated_gig.values
            )
            .rename(index=str, columns={0: "AUPRC", 1: "AUROC"})
            .assign(num_lfs=p_success),
            sort=False
        )
        .reset_index()
        .drop("index", axis=1)
    )
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))

# %%
db_coverage = pd.Series(pd.np.any(new_L[:, ds_start:7], axis=1)).astype(int)
print(db_coverage.value_counts())
db_coverage.mean()

#absent_coverage = pd.Series(pd.np.any(new_L[:, 7:ds_end], axis=1)).astype(int)
#random_coverage = pd.Series(pd.np.any(new_L[:,9:10], axis=1)).astype(int)
#(absent_coverage+random_coverage).value_counts()
# Out:
# 0    2256199
# 1     568063
# dtype: int64
# 0.2011367925496997

# %% [markdown]
# ## Dev Set Performance (AUPRC, AUROC)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10, 5))
sns.pointplot(x="num_lfs", y="AUPRC", data=dev_gig_pos_df, ax=axs[0])
sns.pointplot(x="num_lfs", y="AUROC", data=dev_gig_pos_df, ax=axs[1])
axs[1].set_ylim([0.5,1])
# Out:
# /home/danich1/anaconda2/envs/snorkeling/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0.5, 1)

# %% [markdown]
# ## Test Set Performance (AUPRC, AUROC)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10, 5))
sns.pointplot(x="num_lfs", y="AUPRC", data=test_gig_pos_df, ax=axs[0])
sns.pointplot(x="num_lfs", y="AUROC", data=test_gig_pos_df, ax=axs[1])
axs[1].set_ylim([0.5,1])
# Out:
# /home/danich1/anaconda2/envs/snorkeling/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0.5, 1)

# %%
dev_gig_pos_df.to_csv(
    "results/error_analysis/pos_random_lf_dev_performance.tsv", 
    index=False, sep="\t", float_format="%.5g"
)

test_gig_pos_df.to_csv(
    "results/error_analysis/pos_random_lf_test_performance.tsv", 
    index=False, sep="\t", float_format="%.5g"
)

# %% [markdown]
# # Random Label Function Negative Direction

# %% [markdown]
# This block is designed to determine how many label functions are needed to achieve decent results.

# %%
num_of_samples = 50
regularization_grid = pd.np.round(pd.np.linspace(0.01, 5, num=5), 2)

# %%
dev_gig_neg_df = pd.DataFrame(dev_baseline)
test_gig_neg_df = pd.DataFrame(test_baseline)

#dev_gig_marginals_df = pd.DataFrame(dev_baseline_marginals, columns=["marginals", "label"]).assign(num_lfs=0)
#test_gig_marginals_df = pd.DataFrame(test_baseline_marginals, columns=["marginals", "label"]).assign(num_lfs=0)

pd.np.random.seed(100)
frequency = [0.25, 0.5, 0.75, 1]

for p_success in frequency:
    
    dev_random_grid = {}
    test_random_grid = {}
    
    for sample in tqdm_notebook(range(num_of_samples)):
        random_lf = pd.np.random.binomial(1, p_success, (correct_L.shape[0], 1)) * 2
        new_L = pd.np.concatenate([correct_L[:, ds_start:ds_end], random_lf], axis=1)

        random_lf = pd.np.random.binomial(1, p_success, (correct_L_dev.shape[0], 1)) * 2
        new_L_dev = pd.np.concatenate([correct_L_dev[:, ds_start:ds_end], random_lf], axis=1)

        random_lf = pd.np.random.binomial(1, p_success, (correct_L_test.shape[0], 1)) * 2
        new_L_test = pd.np.concatenate([correct_L_test[:, ds_start:ds_end], random_lf], axis=1)

        new_dev_grid, new_test_grid = train_baseline_model(
            new_L, new_L_dev, candidate_dfs['dev'].curated_gig.values, 
            new_L_test, list(range(ds_start, ds_end+1)), regularization_grid,
            train_marginal_dir="data/random_sampling/GiG/marginals/"
        )
        dev_random_grid[sample] = new_dev_grid[list(new_dev_grid.keys())[0]]
        test_random_grid [sample] = new_test_grid[list(new_test_grid.keys())[0]]
    
    dev_gig_neg_df=(
        dev_gig_neg_df
        .append(
            generate_results_df(
                dev_random_grid, 
                candidate_dfs['dev'].curated_gig.values
            )
            .rename(index=str, columns={0: "AUPRC", 1: "AUROC"})
            .assign(num_lfs=p_success),
            sort=False
        )
        .reset_index()
        .drop("index", axis=1)
    )
    
    test_gig_neg_df=(
        test_gig_neg_df
        .append(
            generate_results_df(
                test_random_grid, 
                candidate_dfs['test'].curated_gig.values
            )
            .rename(index=str, columns={0: "AUPRC", 1: "AUROC"})
            .assign(num_lfs=p_success),
            sort=False
        )
        .reset_index()
        .drop("index", axis=1)
    )
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))

# %% [markdown]
# ## Dev Set Performance (AUPRC, AUROC)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10, 5))
sns.pointplot(x="num_lfs", y="AUPRC", data=dev_gig_neg_df, ax=axs[0])
sns.pointplot(x="num_lfs", y="AUROC", data=dev_gig_neg_df, ax=axs[1])
axs[1].set_ylim([0.5,1])
# Out:
# /home/danich1/anaconda2/envs/snorkeling/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0.5, 1)

# %% [markdown]
# ## Test Set Performance (AUPRC, AUROC)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10, 5))
sns.pointplot(x="num_lfs", y="AUPRC", data=test_gig_neg_df, ax=axs[0])
sns.pointplot(x="num_lfs", y="AUROC", data=test_gig_neg_df, ax=axs[1])
axs[1].set_ylim([0.5,1])
# Out:
# /home/danich1/anaconda2/envs/snorkeling/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0.5, 1)

# %%
dev_gig_neg_df.to_csv(
    "results/error_analysis/neg_random_lf_dev_performance.tsv", 
    index=False, sep="\t", float_format="%.5g"
)

test_gig_neg_df.to_csv(
    "results/error_analysis/neg_random_lf_test_performance.tsv", 
    index=False, sep="\t", float_format="%.5g"
)
